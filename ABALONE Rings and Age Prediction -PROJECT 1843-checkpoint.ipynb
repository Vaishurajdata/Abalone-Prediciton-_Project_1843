# %% [markdown]
# # Q1.To Predict the Number of Rings and age of each Abalone by using the given dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
# Reading the data
abalone_data = pd.read_csv("D:\\Data Trained - Excel links\\abalone.csv")

# Getting the shape
abalone_data.shape
# Out:
# (4177, 9)

# %%
# looking at the head of the data

abalone_data.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
# description of the data
abalone_data.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight        Rings
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     1.000000
# ...

# %%
# Finding the basic information of the data

abalone_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             4177 non-null   object
#  1   Length          4177 non-null   float64
#  2   Diameter        4177 non-null   float64
#  3   Height          4177 non-null   float64
#  4   Whole weight    4177 non-null   float64
#  5   Shucked weight  4177 non-null   float64
#  6   Viscera weight  4177 non-null   float64
#  7   Shell weight    4177 non-null   float64
#  8   Rings           4177 non-null   int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 293.8+ KB

# %%
# checking if there is any NULL data 

abalone_data.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %%
#  To pairplot

sns.pairplot(abalone_data)

# %%
# checking the columns of the data

abalone_data.columns
# Out:
# Index(['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight',
#        'Viscera weight', 'Shell weight', 'Rings'],
#       dtype='object')

# %%
# heatmap

sns.heatmap(abalone_data[[ 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight',
       'Viscera weight', 'Shell weight', 'Rings']])
# Out:
# <AxesSubplot:>

# %%
# finding the values of Sex

abalone_data['Sex'].value_counts()
# Out:
# M    1528
# I    1342
# F    1307
# Name: Sex, dtype: int64

# %%
# plotting a hue plot

plt.rcParams['figure.figsize'] = (18, 8)
sns.boxplot(abalone_data['Rings'], abalone_data['Length'], hue = abalone_data['Sex'], palette = 'pastel')
plt.title('Rings vs length and sex', fontsize = 20)
# Out:
# C:\Users\satya\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Rings vs length and sex')

# %%
# Finding the Rings vs Height and Sex

plt.rcParams['figure.figsize'] = (20, 10)
sns.boxplot(abalone_data['Rings'], abalone_data['Height'], hue = abalone_data['Sex'], palette = 'Set2')
plt.title('Rings vs height and sex', fontsize = 18)
# Out:
# C:\Users\satya\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Rings vs height and sex')

# %%
# Rings vs Diameter and Sex details

plt.rcParams['figure.figsize'] = (25, 9)
sns.violinplot(abalone_data['Rings'], abalone_data['Diameter'], hue = abalone_data['Sex'], palette = 'Set1')
plt.title('Rings vs diameter and sex', fontsize = 25)
# Out:
# C:\Users\satya\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Rings vs diameter and sex')

# %%
# Finding the  Rings vs Viscera weight

plt.rcParams['figure.figsize'] = (16, 9)
sns.stripplot(abalone_data['Rings'], abalone_data['Viscera weight'])
plt.title('Rings vs Viscera Weight')
# Out:
# C:\Users\satya\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Rings vs Viscera Weight')

# %%
# Finding the Ring vs Shucked weight

plt.rcParams['figure.figsize'] = (16, 9)
sns.swarmplot(abalone_data['Rings'], abalone_data['Shucked weight'], palette = 'dark')
plt.title('Rings vs shucked weight')
# Out:
# C:\Users\satya\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\satya\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 46.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\satya\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 66.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\satya\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 64.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
# ...

# %%
# Findinf the  Ring vs Shell weight

plt.rcParams['figure.figsize'] = (16, 9)
sns.regplot(abalone_data['Rings'], abalone_data['Shell weight'])
plt.title('Rings vs Shell weight')
# Out:
# C:\Users\satya\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Rings vs Shell weight')

# %%
#  Finding the relationship between diameter vs lenght

plt.rcParams['figure.figsize'] = (16, 9)
sns.regplot(abalone_data['Diameter'], abalone_data['Length'])
plt.title('Diameter vs Length')
# Out:
# C:\Users\satya\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Diameter vs Length')

# %%
'''
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
abalone_data['Sex'] = le.fit_transform(abalone_data['Sex'])

abalone_data['Sex'].value_counts()
'''

abalone_data = pd.get_dummies(abalone_data)

# %%
abalone_data.head()
# Out:
#    Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings  Sex_F  Sex_I  Sex_M
# 0         0.150     15      0      0      1
# 1         0.070      7      0      0      1
# 2         0.210      9      1      0      0
# 3         0.155     10      0      0      1
# 4         0.055      7      0      1      0

# %% [markdown]
# # Model Training and Evaluations

# %%
# !pip install scikit-learn

# %%
import sklearn as sk

# %%
from sklearn import preprocessing

le = preprocessing.LabelEncoder()
le.fit(abalone_data['Sex'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Sex'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
le.classes_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24460/159436719.py in <module>
# ----> 1 le.classes_
#
# AttributeError: 'LabelEncoder' object has no attribute 'classes_'

# %%
abalone_data['Sex']= le.transform(abalone_data['Sex'])

# %%
le.inverse_transform([2,1,0])

# %%
targets = abalone_data.pop('Rings')
targets
# Out:
# 0       15
# 1        7
# 2        9
# 3       10
# 4        7
#         ..
# 4172    11
# 4173    10
# 4174     9
# 4175    10
# 4176    12
# Name: Rings, Length: 4177, dtype: int64

# %%
features = abalone_data.iloc[:, :-1]
features
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0       2   0.455     0.365   0.095        0.5140          0.2245
# 1       2   0.350     0.265   0.090        0.2255          0.0995
# 2       0   0.530     0.420   0.135        0.6770          0.2565
# 3       2   0.440     0.365   0.125        0.5160          0.2155
# 4       1   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4172    0   0.565     0.450   0.165        0.8870          0.3700
# 4173    2   0.590     0.440   0.135        0.9660          0.4390
# 4174    2   0.600     0.475   0.205        1.1760          0.5255
# 4175    0   0.625     0.485   0.150        1.0945          0.5310
# 4176    2   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight
# 0             0.1010
# 1             0.0485
# 2             0.1415
# 3             0.1140
# 4             0.0395
# ...              ...
# ...

# %%
targets = np.array(targets)
features = np.array(features)

# %%
# split between the datasets
from sklearn.model_selection import train_test_split

Xtrain, Xtest, ytrain, Ytest = train_test_split(features, targets, test_size=0.2, random_state=40)

# %%
# fit only training data
scaler = preprocessing.StandardScaler()
scaler.fit(Xtrain)

#Apply transforms to both training and test set
Xtrain = scaler.transform(Xtrain)
Xtest = scaler.transform(Xtest)

# %%
from sklearn.svm import SVR
from sklearn import svm


svm - SVR(kernel-"poly", C-2, gamma-"auto", degree-3, epsilon-0.6, coef0-1)
#svm = SVR(kernel="rbf", C=2, gamma="auto", degree=3, epsilon=0.6, coef0=1)
#svm = SVR(kernel="linear", C=10, gamma="auto")
svm.fit(Xtrain, Ytrain)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24460/3858866858.py in <module>
#       3
#       4
# ----> 5 svm - SVR(kernel-"poly", C-2, gamma-"auto", degree-3, epsilon-0.6, coef0-1)
#       6 #svm = SVR(kernel="rbf", C=2, gamma="auto", degree=3, epsilon=0.6, coef0=1)
#       7 #svm = SVR(kernel="linear", C=10, gamma="auto")
#
# NameError: name 'kernel' is not defined

# %%
svm_preds - np.floor(svm.predict(Xtest))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24460/390962189.py in <module>
# ----> 1 svm_preds - np.floor(svm.predict(Xtest))
#
# NameError: name 'svm_preds' is not defined

# %%
from sklearn.model_selection import cross_validate

cross_validate(svm, Xtest, Ytest, cv=5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24460/1230844722.py in <module>
#       1 from sklearn.model_selection import cross_validate
#       2
# ----> 3 cross_validate(svm, Xtest, Ytest, cv=5)
#
# NameError: name 'Xtest' is not defined

# %%
from sklearn.metrics import mean_absolute_error
mae = mean_absloute_error(Ytest, svm_preds)
mae
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24460/4017839189.py in <module>
#       1 from sklearn.metrics import mean_absolute_error
# ----> 2 mae = mean_absloute_error(Ytest, svm_preds)
#       3 mae
#
# NameError: name 'mean_absloute_error' is not defined

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(max_depth=2, random_state=0)
rf.fit(Xtest, Ytest)
preds = np.floor(rf.predict(Xtest))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24460/578648872.py in <module>
#       2
#       3 rf = RandomForestRegressor(max_depth=2, random_state=0)
# ----> 4 rf.fit(Xtest, Ytest)
#       5 preds = np.floor(rf.predict(Xtest))
#
# NameError: name 'Xtest' is not defined

# %%
cross_validate(rf, Xtest, Ytest, cv=5)
# Out:
# {'fit_time': array([0.09608626, 0.07900023, 0.07799983, 0.07700014, 0.07800031]),
#  'score_time': array([0.00599957, 0.00399971, 0.00399995, 0.00499964, 0.00399971]),
#  'test_score': array([0.35683891, 0.22305686, 0.35050778, 0.36338831, 0.38197851])}

# %%
mae = mean_absolute_error(Ytest, preds)
mae
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24460/2572473752.py in <module>
# ----> 1 mae = mean_absolute_error(Ytest, preds)
#       2 mae
#
# NameError: name 'mean_absolute_error' is not defined

# %%
from sklearn.linear_model import SGDRegressor

sgd = RandomForestRegressor(max_depth=2, random_state=0)
sgd.fit(Xtest, Ytest)
preds = np.floor(sgd.predict(Xtest))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24460/2952563615.py in <module>
#       2
#       3 sgd = RandomForestRegressor(max_depth=2, random_state=0)
# ----> 4 sgd.fit(Xtest, Ytest)
#       5 preds = np.floor(sgd.predict(Xtest))
#
# NameError: name 'Xtest' is not defined

# %%
cross_validate(sgd, Xtest, Ytest, cv=5)

# %%
mae = mean_absolute_error(Ytest, preds)
mae

# %%
from sklearn.neighbors import KNeighborsRegressor as nn

knn - nn(8, weight-'uniform')
knn.fit(Xtrain, Ytrain)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24460/951185688.py in <module>
#       1 from sklearn.neighbors import KNeighborsRegressor as nn
#       2
# ----> 3 knn - nn(8, weights-'uniform')
#       4 knn.fit(Xtrain, Ytrain)
#
# NameError: name 'weights' is not defined

# %%
cross_validation(knn, Xtest, Ytest, cv-5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24460/3404671182.py in <module>
# ----> 1 cross_validation(knn, Xtest, Ytest, cv-5)
#
# NameError: name 'cross_validation' is not defined

# %%
preds - np.floor(knn.predict(Xtest))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24460/2464672211.py in <module>
# ----> 1 preds - np.floor(knn.predict(Xtest))
#
# NameError: name 'preds' is not defined

# %%
mae = mean_absolute_error(Ytest, preds)
mae
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24460/2572473752.py in <module>
# ----> 1 mae = mean_absolute_error(Ytest, preds)
#       2 mae
#
# NameError: name 'mean_absolute_error' is not defined

# %%
npoints = len(Xtest)
graph_points = np.random.randint(npoints)
xdata = range(len(Xtest[:graph_points]))
ydata = Ytest[:grapgh_points]
ypreds = svm_preds[:grapgh_points]
plt.title("Results and predictions", size=18)
plt.xlabel('Prediction Number', size=14)
ply.ylabel('Abalone Rings', size=14)
plt.scatter(xdata, ydata, color='green', alpha=0.5)
plt.scatter(xdata, ypreds, color='yellow', alpha=0.4)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24460/1814796517.py in <module>
# ----> 1 npoints = len(Xtest)
#       2 graph_points = np.random.randint(npoints)
#       3 xdata = range(len(Xtest[:graph_points]))
#       4 ydata = Ytest[:grapgh_points]
#       5 ypreds = svm_preds[:grapgh_points]
#
# NameError: name 'Xtest' is not defined

# %%
  # I tried many times to solve all ERROR inputs - but failed and sorted many ways to solve but couldnot done.
    Submitting Partillay the assignment problem
